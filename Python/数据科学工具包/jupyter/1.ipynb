# %%
a = 1
b = 2
print(a + b)
# Out:
# 3

# %%
print(a * b)
# Out:
# 2

# %%
# !uv add numpy==2.5.1
# Out:
# Resolved 2 packages in 14ms
# Checked 1 package in 0.70ms

# %%
import numpy as np

# %%
arr = np.array([1,2,3, [1,3]])
print(arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 arr = np.array([1,2,3, [1,3]])
#       2 print(arr)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.

# %%
import numpy as np
arr = np.array([[1,2,3], [4,5,6]], dtype=np.int64)
print(arr)
print(f'维度：{arr.ndim}')
print(f'size:{arr.size}')
print(f'shape:{arr.shape}')
print(f'步幅:{arr.strides}') # (24, 8)

t = arr.T
print(t) # 和arr公用一块内存空间
# Out:
# [[1 2 3]
#  [4 5 6]]
# 维度：2
# size:6
# shape:(2, 3)
# 步幅:(24, 8)
# [[1 4]
#  [2 5]
#  [3 6]]
